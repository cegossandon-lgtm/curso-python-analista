# %%
mensaje = "Hola desde un Jupyter Notebook"
print(mensaje)
# Out:
# Hola desde un Jupyter Notebook

# %%
print(mensaje)
# Out:
# Hola desde un Jupyter Notebook

# %%
mensaje = "Este es un mensaje distinto"

# %%
import pandas as pd

tabla = pd.read_excel("../clase-20/clientes_sucios.xlsx")
tabla.head()
# Out:
#    id_cliente         nombre  monto_compra              sucursal
# 0           1      Ana Rojas           NaN   Sucursal Las Condes
# 1           2   Javier Pérez      122155.0        SUCURSAL MAIPU
# 2           3    María Vidal           NaN   sucursal Concepción
# 3           4    Pedro Silva       19834.0  Sucursal Providencia
# 4           5  Andrés Torres           NaN   sucursal Concepción

# %%
tabla.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5300 entries, 0 to 5299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_cliente    5300 non-null   int64
#  1   nombre        5300 non-null   str
#  2   monto_compra  2677 non-null   float64
#  3   sucursal      5300 non-null   str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 165.8 KB

# %%
tabla["sucursal"].value_counts()
# Out:
# sucursal
# Sucursal Providencia     1118
# sucursal Concepción      1064
# SUCURSAL MAIPU           1059
# Sucursal Providencia     1056
# Sucursal Las Condes      1003
# Name: count, dtype: int64
